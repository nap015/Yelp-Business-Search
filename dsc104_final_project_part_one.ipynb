# %%
import pandas as pd
import numpy as np
import csv
import json

# %% [markdown]
# # Cleaning

# %%
# read in data
df_list = []
for chunk in pd.read_json('yelp_academic_dataset_business.json', chunksize=200, lines=True):
    df_list.append(chunk)
df = pd.concat(df_list)

# %%
# clean table for faster loading
df.dropna(subset=['categories','hours','state'], inplace=True)
df = df[df['categories'].str.contains("Restaurants")]
df = df[df['is_open']==1]
df = df[~df['state'].isin(['ON','AB','QC','MB','BC'])]
df = df[~df['postal_code'].str.contains(" ")]
df = df.drop(columns=['attributes'])
df.head()
# Out:
#                business_id                             name  \
# 8   pQeaRpvuhoEqudo3uymHIQ              The Empanadas House
# 33  vjTVxnsQEZ34XjYNS-XUpA                Wetzel's Pretzels
# 41  98hyK2QEUeI8v2y0AghfZA  Pho Lee's Vietnamese Restaurant
# 49  tLpkSwdtqqoXwU0JAGnApw                          Wendy's
# 54  lK-wuiq8b1TuU7bfbQZgsg                        Hingetown
#
#                          address       city state postal_code   latitude  \
# 8                 404 E Green St  Champaign    IL       61820  40.110446
# 33  4550 East Cactus Rd, #KSFC-4    Phoenix    AZ       85032  33.602822
# 41       1541 E 38th St, Ste 101  Cleveland    OH       44114  41.512155
# 49          4602 Northfield Road  Cleveland    OH       44128  41.434614
# 54                                Cleveland    OH       44113  41.489343
#
#      longitude  stars  review_count  is_open  \
# 8   -88.233073    4.5             5        1
# 33 -111.983533    4.0            10        1
# 41  -81.663332    4.5            23        1
# 49  -81.527026    3.5             7        1
# 54  -81.711029    3.0             4        1
#
#                                            categories  \
# 8   Ethnic Food, Food Trucks, Specialty Food, Impo...
# 33   Food, Pretzels, Bakeries, Fast Food, Restaurants
# 41                      Restaurants, Vietnamese, Soup
# 49                    Restaurants, Fast Food, Burgers
# 54  Shopping Centers, Food, Coffee & Tea, Cafes, M...
#
#                                                 hours
# 8   {'Monday': '11:30-14:30', 'Tuesday': '11:30-14...
# 33  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 41  {'Monday': '11:0-20:0', 'Wednesday': '11:0-20:...
# 49  {'Monday': '10:0-3:0', 'Tuesday': '10:0-3:0', ...
# 54  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...

# %%
# # export to csv: for python script
# df.to_csv('yelp_business.csv',index=False)

# %% [markdown]
# # Cassandra

# %%
# # import from csv: for python script
# df = pd.read_csv('yelp_business.csv')
# df.head()

# %%
# start cassandra cluster
from cassandra.cluster import Cluster
cluster = Cluster(['cassandra'])
session = cluster.connect()

# %%
# make keyspace
session.execute(
    "CREATE KEYSPACE IF NOT EXISTS ks "
    "WITH REPLICATION = { 'class' : 'SimpleStrategy', 'replication_factor' : 3 };"
)

session.set_keyspace('ks')

# %%
# session.execute("""
# DROP TABLE business;
# """)

# %%
# make table
session.execute("""
CREATE TABLE business(
   id text,
   name text,
   address text,
   city text,
   state text,
   stars float,
   review_count int,
   is_open int,
   categories text,
   hours text,
   PRIMARY KEY (id, name)
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationTimedOut                         Traceback (most recent call last)
# <ipython-input-9-56d5b2c1ec3b> in <module>
#      14    PRIMARY KEY (id, name)
#      15 );
# ---> 16 """)
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# OperationTimedOut: errors={'Connection defunct by heartbeat': 'Client request timeout. See Session.execute[_async](timeout)'}, last_host=10.40.224.55:9042

# %%
# insert dataframe into table
query = "INSERT INTO business (id, name, address, city, state, stars, review_count, is_open, categories, hours)  VALUES (?,?,?,?,?,?,?,?,?,?)"
prepared = session.prepare(query)

for index, item in df.iterrows():
    session.execute(prepared, (item[0], item[1], str(item[2]), item[3], item[4], item[8], item[9], item[10], item[11], str(item[12])))
# Out:
# ---------------------------------------------------------------------------
# WriteTimeout                              Traceback (most recent call last)
# <ipython-input-11-7083bca26c99> in <module>
#       4
#       5 for index, item in df.iterrows():
# ----> 6     session.execute(prepared, (item[0], item[1], str(item[2]), item[3], item[4], item[8], item[9], item[10], item[11], str(item[12])))
#       7
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# WriteTimeout: Error from server: code=1100 [Coordinator node timed out waiting for replica nodes' responses] message="Operation timed out - received only 0 responses." info={'consistency': 'LOCAL_ONE', 'required_responses': 1, 'received_responses': 0, 'write_type': 'SIMPLE'}

# %%
# make queries on state
query = """
SELECT id, name, address, city, state, stars, review_count, is_open, categories, hours
FROM business
WHERE state = %s and is_open = 1
ALLOW FILTERING;
"""

rows = session.execute(query, ('AZ', )) # input example AZ for state

# export query results to csv
header = ['id','name', 'address', 'city', 'state', 'stars', 'review_count', 'categories', 'hours']
cdf = pd.DataFrame(columns=header)

for row in rows:
    line = [row.id, row.name, row.address, row.city, row.state, row.stars, row.review_count, row.categories, row.hours]
    cdf = pd.concat([pd.DataFrame([line],columns=cdf.columns), cdf])

# with open('test.csv', 'w') as fp:
#     writer = csv.writer(fp, delimiter=',')
#     writer.writerow(header)
#     for row in rows:
#         writer.writerow([row.id, row.name, row.address, row.city, row.state, row.stars, row.review_count, row.categories, row.hours])

# %%
cdf = cdf.reset_index(drop=True)
cdf
# Out:
#                          id                             name  \
# 0    LGEIsxeJQATo9J1IA-TEdA    Fajitas A Sizzlin Celebration
# 1    -i0DZp5-KT54MpqvREmqXQ                    Pho Tan Thanh
# 2    AcjO26DmOhqWlfo2s5DUow              Stackers Restaurant
# 3    zJGtD3y-pAIGNId4codEEg                        Otro Cafe
# 4    X54yOvzhEKyAurDOeQ-BkA               QDOBA Mexican Eats
# ..                      ...                              ...
# 718  b1m_PK-ggGR3CmBjdIyqkQ  Wrights at The Arizona Biltmore
# 719  cCX_cpuuzTI3lDUyKFCnAg         Filiberto's Mexican Food
# 720  64E4jIkHN20RVJoaM2fyGw                       O'Kelley's
# 721  rMCKv9puuu2NkYISHnwyWg                          Rubio's
# 722  T4hXOBXNU5hq694fjpz1Ng                 Mother's Tamales
#
#                                      address     city state  stars  \
# 0                    9841 N Black Canyon Hwy  Phoenix    AZ    3.5
# 1                           7505 W Cactus Rd   Peoria    AZ    3.5
# 2                   2855 W Cactus Rd, Ste 24  Phoenix    AZ    3.5
# 3                              6035 N 7th St  Phoenix    AZ    4.0
# 4    3300 W Camelback Rd, Thunder Alley Bldg  Phoenix    AZ    3.0
# ..                                       ...      ...   ...    ...
# 718                      2400 E Missouri Ave  Phoenix    AZ    4.0
# 719                        13972 N. 83rd Ave   Peoria    AZ    3.0
# 720              2120 W Guadalupe Rd, Ste 17     Mesa    AZ    3.5
# 721                   4747 E Bell Rd, Ste 17  Phoenix    AZ    3.5
# 722                         330 S Gilbert Rd     Mesa    AZ    4.5
#
#     review_count                                         categories  \
# 0            328         Salad, Soup, Restaurants, Tex-Mex, Mexican
# 1             92  Ethnic Food, Vietnamese, Specialty Food, Resta...
# 2             83  American (Traditional), Nightlife, Pubs, Bars,...
# 3            808    Restaurants, Mexican, Breakfast & Brunch, Cafes
# 4              6  Fast Food, Restaurants, Mexican, Caterers, Eve...
# ..           ...                                                ...
# 718          139    Restaurants, American (New), Breakfast & Brunch
# 719           99    Mexican, Restaurants, Breakfast & Brunch, Salad
# 720           72  Arts & Entertainment, Music Venues, Nightlife,...
# 721          100  Restaurants, Seafood, Event Planning & Service...
# 722           21           Breakfast & Brunch, Restaurants, Mexican
#
#                                                  hours
# 0    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1    {'Monday': '9:0-21:0', 'Wednesday': '9:0-21:0'...
# 2    {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 3    {'Monday': '0:0-0:0', 'Tuesday': '17:0-22:0', ...
# 4    {'Monday': '0:0-0:0', 'Tuesday': '7:0-23:0', '...
# ..                                                 ...
# 718  {'Monday': '17:30-21:30', 'Tuesday': '17:30-21...
# 719  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 720  {'Monday': '6:0-2:0', 'Tuesday': '6:0-2:0', 'W...
# 721  {'Monday': '10:30-21:0', 'Tuesday': '10:30-21:...
# 722  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
#
# [723 rows x 9 columns]

# %%
# drop table 
session.execute("""
DROP TABLE business;
""")

# %% [markdown]
# # Redis

# %%
# start redis session
import redis
r = redis.Redis(host='my-redis', port=6379, db=0,decode_responses=True)

# %%
# load query result from cassandra
#cdf = pd.read_csv('test.csv')
#cdf

# %%
# populate redis with query result
pipe = r.pipeline()

for i in range(len(cdf)):
    id_ = i
    pipe.hmset(id_, {'business_id': cdf['id'][i],
                     'name': cdf['name'][i],
                     'address': cdf['address'][i],
                     'city': cdf['city'][i], 
                     'state': cdf['state'][i],
                     'stars': cdf['stars'][i],
                     'review_count': cdf['review_count'][i],
                     'categories': cdf['categories'][i],
                     'hours': cdf['hours'][i]})
    pipe.zadd(cdf['city'][i], {id_:i})
pipe.execute()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Pipeline.hmset() is deprecated. Use Pipeline.hset() instead.
# [True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  True,
#  1,
#  ...]

# %%
# query on city; print out output to a JSON file
with open('test.json', 'w') as f:
    for x in r.zrangebyscore('Phoenix', 0, len(cdf)):
        pipe.hgetall(x)
    json.dump(pipe.execute(),f)

# %% [markdown]
# # Check Output

# %%
test_list = []
test = pd.read_json('test.json')
test
# Out:
#     state                                         categories  stars  \
# 0      AZ         Salad, Soup, Restaurants, Tex-Mex, Mexican    3.5
# 1      AZ  American (Traditional), Nightlife, Pubs, Bars,...    3.5
# 2      AZ    Restaurants, Mexican, Breakfast & Brunch, Cafes    4.0
# 3      AZ  Fast Food, Restaurants, Mexican, Caterers, Eve...    3.0
# 4      AZ  American (Traditional), Bars, Tex-Mex, Nightli...    2.5
# ..    ...                                                ...    ...
# 227    AZ                         Food, Mexican, Restaurants    3.0
# 228    AZ                                 Pizza, Restaurants    3.0
# 229    AZ            Food Trucks, Food, Restaurants, Mexican    4.5
# 230    AZ    Restaurants, American (New), Breakfast & Brunch    4.0
# 231    AZ  Restaurants, Seafood, Event Planning & Service...    3.5
#
#                 business_id  review_count                             name  \
# 0    LGEIsxeJQATo9J1IA-TEdA           328    Fajitas A Sizzlin Celebration
# 1    AcjO26DmOhqWlfo2s5DUow            83              Stackers Restaurant
# 2    zJGtD3y-pAIGNId4codEEg           808                        Otro Cafe
# 3    X54yOvzhEKyAurDOeQ-BkA             6               QDOBA Mexican Eats
# 4    2SHu52w_w4Z4ACq-vx3a-Q            78                          Chili's
# ..                      ...           ...                              ...
# 227  ERM603jbIbNqX2c7Ww1Qiw            89                         Cafe Rio
# 228  8F9C5vhDlYphBWELUgLkvQ            94               Famous Ray's Pizza
# 229  VJVEDDJKccmrW1fhJCWmsQ           104             Taqueria La Hacienda
# 230  b1m_PK-ggGR3CmBjdIyqkQ           139  Wrights at The Arizona Biltmore
# 231  rMCKv9puuu2NkYISHnwyWg           100                          Rubio's
#
#                                      address     city  \
# 0                    9841 N Black Canyon Hwy  Phoenix
# 1                   2855 W Cactus Rd, Ste 24  Phoenix
# 2                              6035 N 7th St  Phoenix
# 3    3300 W Camelback Rd, Thunder Alley Bldg  Phoenix
# 4                            2612 N 75th Ave  Phoenix
# ..                                       ...      ...
# 227                       12005 N Tatum Blvd  Phoenix
# 228                   2501 W Happy Valley Rd  Phoenix
# 229                         254 E Buckeye Rd  Phoenix
# 230                      2400 E Missouri Ave  Phoenix
# 231                   4747 E Bell Rd, Ste 17  Phoenix
#
#                                                  hours
# 0    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1    {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 2    {'Monday': '0:0-0:0', 'Tuesday': '17:0-22:0', ...
# 3    {'Monday': '0:0-0:0', 'Tuesday': '7:0-23:0', '...
# 4    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# ..                                                 ...
# 227  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 228  {'Monday': '10:0-21:30', 'Tuesday': '10:0-21:3...
# 229  {'Monday': '8:30-0:0', 'Tuesday': '8:30-0:0', ...
# 230  {'Monday': '17:30-21:30', 'Tuesday': '17:30-21...
# 231  {'Monday': '10:30-21:0', 'Tuesday': '10:30-21:...
#
# [232 rows x 9 columns]
