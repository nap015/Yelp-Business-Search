# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Cleaning

# %%
# read in data
df_list = []
for chunk in pd.read_json('yelp_academic_dataset_business.json', chunksize=200, lines=True):
    df_list.append(chunk)
df = pd.concat(df_list)

# %%
# clean table for faster loading
df.dropna(subset=['categories','hours','state'], inplace=True)
df = df[df['categories'].str.contains("Restaurants")]
df = df[df['is_open']==1]
df = df[~df['state'].isin(['ON','AB','QC','MB','BC'])]
df = df[~df['postal_code'].str.contains(" ")]
df = df.drop(columns=['attributes'])
df.head()
# Out:
#                business_id                             name  \
# 8   pQeaRpvuhoEqudo3uymHIQ              The Empanadas House
# 33  vjTVxnsQEZ34XjYNS-XUpA                Wetzel's Pretzels
# 41  98hyK2QEUeI8v2y0AghfZA  Pho Lee's Vietnamese Restaurant
# 49  tLpkSwdtqqoXwU0JAGnApw                          Wendy's
# 54  lK-wuiq8b1TuU7bfbQZgsg                        Hingetown
#
#                          address       city state postal_code   latitude  \
# 8                 404 E Green St  Champaign    IL       61820  40.110446
# 33  4550 East Cactus Rd, #KSFC-4    Phoenix    AZ       85032  33.602822
# 41       1541 E 38th St, Ste 101  Cleveland    OH       44114  41.512155
# 49          4602 Northfield Road  Cleveland    OH       44128  41.434614
# 54                                Cleveland    OH       44113  41.489343
#
#      longitude  stars  review_count  is_open  \
# 8   -88.233073    4.5             5        1
# 33 -111.983533    4.0            10        1
# 41  -81.663332    4.5            23        1
# 49  -81.527026    3.5             7        1
# 54  -81.711029    3.0             4        1
#
#                                            categories  \
# 8   Ethnic Food, Food Trucks, Specialty Food, Impo...
# 33   Food, Pretzels, Bakeries, Fast Food, Restaurants
# 41                      Restaurants, Vietnamese, Soup
# 49                    Restaurants, Fast Food, Burgers
# 54  Shopping Centers, Food, Coffee & Tea, Cafes, M...
#
#                                                 hours
# 8   {'Monday': '11:30-14:30', 'Tuesday': '11:30-14...
# 33  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 41  {'Monday': '11:0-20:0', 'Wednesday': '11:0-20:...
# 49  {'Monday': '10:0-3:0', 'Tuesday': '10:0-3:0', ...
# 54  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...

# %%
# # export to csv: for python script
# df.to_csv('yelp_business.csv',index=False)

# %% [markdown]
# # Cassandra

# %%
# # import from csv: for python script
# df = pd.read_csv('yelp_business.csv')
# df.head()

# %%
# start cassandra cluster
from cassandra.cluster import Cluster
cluster = Cluster(['cassandra'])
session = cluster.connect()

# %%
# make keyspace
session.execute(
    "CREATE KEYSPACE IF NOT EXISTS ks "
    "WITH REPLICATION = { 'class' : 'SimpleStrategy', 'replication_factor' : 3 };"
)

session.set_keyspace('ks')

# %%
session.execute("""
DROP TABLE business;
""")
# Out:
# ---------------------------------------------------------------------------
# OperationTimedOut                         Traceback (most recent call last)
# <ipython-input-53-30c30e909a77> in <module>
#       1 session.execute("""
#       2 DROP TABLE business;
# ----> 3 """)
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# OperationTimedOut: errors={'10.37.0.58:9042': 'Client request timeout. See Session.execute[_async](timeout)'}, last_host=10.37.0.58:9042
# WARNING:cassandra.cluster:Node 10.42.0.3:9042 is reporting a schema disagreement: {UUID('b22628e2-41a8-33ac-bb26-b508d68e391a'): [<DefaultEndPoint: 10.40.224.55:9042>, <DefaultEndPoint: 10.42.0.3:9042>], UUID('a019f9f1-a353-36f9-b07c-bc69c237414a'): [<DefaultEndPoint: 10.37.0.58:9042>]}

# %%
# make table
session.execute("""
CREATE TABLE business(
   id text,
   name text,
   address text,
   city text,
   state text,
   stars text,
   review_count int,
   is_open int,
   categories text,
   hours text,
   PRIMARY KEY (id, name)
);
""")

# %%
# insert dataframe into table
query = "INSERT INTO business (id, name, address, city, state, stars, review_count, is_open, categories, hours)  VALUES (?,?,?,?,?,?,?,?,?,?)"
prepared = session.prepare(query)

for index, item in df.iterrows():
    session.execute(prepared, (item[0], item[1], str(item[2]), item[3], item[4], item[8], item[9], item[10], item[11], item[12]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-5fe56c03f569> in <module>
#       3
#       4 for index, item in df.iterrows():
# ----> 5     session.execute(prepared, (item[0], item[1], str(item[2]), item[3], item[4], item[8], item[9], item[10], item[11], item[12]))
#       6
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# /opt/conda/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# make queries on state
query = """
SELECT id, name, address, city, state, stars, review_count, is_open, categories, hours
FROM business
WHERE state = %s and is_open = 1
ALLOW FILTERING;
"""

rows = session.execute(query, ('AZ', )) # input example AZ for state

# export query results to csv

header = ['id','name', 'address', 'city', 'state', 'stars', 'review_count', 'categories', 'hours']
with open('test.csv', 'w') as fp:
    writer = csv.writer(fp, delimiter=',')
    writer.writerow(header)
    for row in rows:
        writer.writerow([row.id, row.name, row.address, row.city, row.state, row.stars, row.review_count, row.categories, row.hours])

# %%
# drop table 
session.execute("""
DROP TABLE business;
""")

# %% [markdown]
# # Redis

# %%
# start redis session
import redis
r = redis.Redis(host='my-redis', port=6379, db=0,decode_responses=True)

# %%
# load query result from cassandra
cdf = pd.read_csv('test.csv')
#cdf
# Out:
#                          id                             name  \
# 0    T4hXOBXNU5hq694fjpz1Ng                 Mother's Tamales
# 1    rMCKv9puuu2NkYISHnwyWg                          Rubio's
# 2    64E4jIkHN20RVJoaM2fyGw                       O'Kelley's
# 3    b1m_PK-ggGR3CmBjdIyqkQ  Wrights at The Arizona Biltmore
# 4    2Umo6re4oAAd_GkP5RFWwQ                      Whataburger
# ..                      ...                              ...
# 508  G_1M9_yX5ThAROn1zKKpQg                    Panda Express
# 509  fl34c5BlCWmSL_BQk-cnaQ                       Which Wich
# 510  zJGtD3y-pAIGNId4codEEg                        Otro Cafe
# 511  AcjO26DmOhqWlfo2s5DUow              Stackers Restaurant
# 512  LGEIsxeJQATo9J1IA-TEdA    Fajitas A Sizzlin Celebration
#
#                          address      city state  stars  review_count  \
# 0               330 S Gilbert Rd      Mesa    AZ    4.5            21
# 1         4747 E Bell Rd, Ste 17   Phoenix    AZ    3.5           100
# 2    2120 W Guadalupe Rd, Ste 17      Mesa    AZ    3.5            72
# 3            2400 E Missouri Ave   Phoenix    AZ    4.0           139
# 4      14251 W Indian School Byp  Goodyear    AZ    2.5            57
# ..                           ...       ...   ...    ...           ...
# 508         11555 W Van Buren St  Avondale    AZ    2.5            41
# 509    2795 S Market St, Ste 110   Gilbert    AZ    3.5           107
# 510                6035 N 7th St   Phoenix    AZ    4.0           808
# 511     2855 W Cactus Rd, Ste 24   Phoenix    AZ    3.5            83
# 512      9841 N Black Canyon Hwy   Phoenix    AZ    3.5           328
#
#                                             categories  \
# 0             Breakfast & Brunch, Restaurants, Mexican
# 1    Restaurants, Seafood, Event Planning & Service...
# 2    Arts & Entertainment, Music Venues, Nightlife,...
# 3      Restaurants, American (New), Breakfast & Brunch
# 4    Restaurants, Fast Food, Burgers, American (Tra...
# ..                                                 ...
# 508                    Fast Food, Restaurants, Chinese
# 509          Seafood, Sandwiches, Restaurants, Italian
# 510    Restaurants, Mexican, Breakfast & Brunch, Cafes
# 511  American (Traditional), Nightlife, Pubs, Bars,...
# 512         Salad, Soup, Restaurants, Tex-Mex, Mexican
#
#                                                  hours
# 0    {'Friday': '9:0-21:0', 'Monday': '9:0-21:0', '...
# 1    {'Friday': '10:30-21:30', 'Monday': '10:30-21:...
# 2    {'Friday': '6:0-2:0', 'Monday': '6:0-2:0', 'Sa...
# 3    {'Friday': '17:30-21:30', 'Monday': '17:30-21:...
# 4    {'Friday': '0:0-0:0', 'Monday': '0:0-0:0', 'Sa...
# ..                                                 ...
# 508  {'Friday': '10:0-21:30', 'Monday': '10:0-21:30...
# 509  {'Friday': '9:0-21:0', 'Monday': '9:0-21:0', '...
# 510  {'Friday': '8:0-22:0', 'Monday': '0:0-0:0', 'S...
# 511  {'Friday': '11:0-2:0', 'Monday': '11:0-1:0', '...
# 512  {'Friday': '11:0-23:0', 'Monday': '11:0-22:0',...
#
# [513 rows x 9 columns]

# %%
# populate redis with query result
pipe = r.pipeline()
for i in range(len(cdf)):
    id_ = i
    pipe.hmset(id_, {'business_id': cdf['business_id'][i],
                     'name': cdf['name'][i],
                     'address': cdf['address'][i],
                     'city': cdf['city'][i], 
                     'state': cdf['state'][i],
                     'stars': float(cdf['stars'][i]),
                     'review_count': int(cdf['review_count'][i]),
                     'categories': cdf['categories'][i],
                     'hours': cdf['hours'][i]})
    pipe.zadd(cdf['city'][i], {id_:i})
pipe.execute()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Pipeline.hmset() is deprecated. Use Pipeline.hset() instead.
#   # This is added back by InteractiveShellApp.init_path()
# [True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  True,
#  0,
#  ...]

# %%
# for x in r.zrangebyscore('Phoenix', 0, len(cdf)):
#     pipe.hgetall(str(x))
#     #json.dump(pipe.hgetall(str(x.decode())),f)
#     #r.hgetall(str(x.decode()))
# pipe.execute()

# %%
# query on city; print out output to a JSON file
with open('test.json', 'w') as f:
    for x in r.zrangebyscore('Phoenix', 0, len(cdf)):
        pipe.hgetall(x)
    json.dump(pipe.execute(),f)

# %% [markdown]
# # Check Output

# %%
# check if output is formatted correctly
test_list = []
test = pd.read_json('test.json')
test
# Out:
#                                 name state  \
# 0                            Rubio's    AZ
# 1    Wrights at The Arizona Biltmore    AZ
# 2                 Famous Ray's Pizza    AZ
# 3                           Cafe Rio    AZ
# 4                        Crazy Jim's    AZ
# ..                               ...   ...
# 166          Hong Kong Asian Cuisine    AZ
# 167                Chambers on First    AZ
# 168                        Otro Cafe    AZ
# 169              Stackers Restaurant    AZ
# 170    Fajitas A Sizzlin Celebration    AZ
#
#                                             categories  \
# 0    Restaurants, Seafood, Event Planning & Service...
# 1      Restaurants, American (New), Breakfast & Brunch
# 2                                   Pizza, Restaurants
# 3                           Food, Mexican, Restaurants
# 4    Mediterranean, Pizza, Greek, Breakfast & Brunc...
# ..                                                 ...
# 166       Japanese, Chinese, Asian Fusion, Restaurants
# 167  American (New), Bars, Restaurants, Pubs, Night...
# 168    Restaurants, Mexican, Breakfast & Brunch, Cafes
# 169  American (Traditional), Nightlife, Pubs, Bars,...
# 170         Salad, Soup, Restaurants, Tex-Mex, Mexican
#
#                                                  hours     city  stars  \
# 0    {'Friday': '10:30-21:30', 'Monday': '10:30-21:...  Phoenix    3.5
# 1    {'Friday': '17:30-21:30', 'Monday': '17:30-21:...  Phoenix    4.0
# 2    {'Friday': '10:0-22:30', 'Monday': '10:0-21:30...  Phoenix    3.0
# 3    {'Friday': '10:30-23:0', 'Monday': '10:30-22:0...  Phoenix    3.0
# 4    {'Friday': '6:30-14:30', 'Monday': '0:0-0:0', ...  Phoenix    3.5
# ..                                                 ...      ...    ...
# 166  {'Friday': '11:0-22:0', 'Monday': '11:0-21:30'...  Phoenix    2.5
# 167  {'Friday': '11:0-2:0', 'Monday': '11:0-2:0', '...  Phoenix    4.0
# 168  {'Friday': '8:0-22:0', 'Monday': '0:0-0:0', 'S...  Phoenix    4.0
# 169  {'Friday': '11:0-2:0', 'Monday': '11:0-1:0', '...  Phoenix    3.5
# 170  {'Friday': '11:0-23:0', 'Monday': '11:0-22:0',...  Phoenix    3.5
#
#                           address  review_count
# 0          4747 E Bell Rd, Ste 17           100
# 1             2400 E Missouri Ave           139
# 2          2501 W Happy Valley Rd            94
# 3              12005 N Tatum Blvd            89
# 4    305 W Washington St, Ste 104            97
# ..                            ...           ...
# 166    3170 W Carefree Hwy, Ste 1            82
# 167                  705 N 1st St            96
# 168                 6035 N 7th St           808
# 169      2855 W Cactus Rd, Ste 24            83
# 170       9841 N Black Canyon Hwy           328
#
# [171 rows x 8 columns]
